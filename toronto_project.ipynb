# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto
# <hr>

# %% [markdown]
# ## **PART 1**: Grabbing & Cleaning the Data

# %%
#installing beautifulsoup and geopy
# !conda install -c anaconda beautifulsoup4 --yes
# !conda install -c conda-forge geopy --yes
#!conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.9.0       |           py36_0         165 KB  anaconda
#     ca-certificates-2020.1.1   |                0         132 KB  anaconda
#     certifi-2020.4.5.1         |           py36_0         159 KB  anaconda
#     openssl-1.1.1g             |       h7b6447c_0         3.8 MB  anaconda
#     soupsieve-2.0              |             py_0          33 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         4.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   beautifulsoup4     anaconda/linux-64::beautifulsoup4-4.9.0-py36_0
#   soupsieve          anaconda/noarch::soupsieve-2.0-py_0
#
# The following packages will be UPDATED:
#
#   openssl            conda-forge::openssl-1.1.1f-h516909a_0 --> anaconda::openssl-1.1.1g-h7b6447c_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2020.4.5~ --> anaconda::ca-certificates-2020.1.1-0
#   certifi            conda-forge::certifi-2020.4.5.1-py36h~ --> anaconda::certifi-2020.4.5.1-py36_0
#
#
#
# Downloading and Extracting Packages
# certifi-2020.4.5.1   | 159 KB    | ##################################### | 100%
# soupsieve-2.0        | 33 KB     | ##################################### | 100%
# ca-certificates-2020 | 132 KB    | ##################################### | 100%
# openssl-1.1.1g       | 3.8 MB    | ##################################### | 100%
# beautifulsoup4-4.9.0 | 165 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#
# The following packages will be UPDATED:
#
#   ca-certificates      anaconda::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.4.5.1-hecc5488_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi               anaconda::certifi-2020.4.5.1-py36_0 --> conda-forge::certifi-2020.4.5.1-py36h9f0ad1d_0
#   openssl               anaconda::openssl-1.1.1g-h7b6447c_0 --> conda-forge::openssl-1.1.1g-h516909a_0
#
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
#importing necessary libraries
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd
from geopy.geocoders import Nominatim
from sklearn.cluster import KMeans
import folium
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
#define the url and read the page
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
content=requests.get(url).text

# %%
#define beautifulsoup object to extract information
bsobj=bs(content,'html.parser')

# %%
#we are interested in grabbing the table. I will use find_all to grab html table which contains the tag 'table'
tables=bsobj.find_all('table')
#the desired table is the first on in the list:
table=tables[0]

# %% [markdown]
# #### Now I will grab each row which starts with <tr> and ends with </tr> and store it in a list
# #### I'm removing the new lines characters '\n' and grabbing the content of the cell by selecting the letters that come after "\<td>" and before "<\td>"

# %%
#First I will grab the headers
headers=[]
for td in (table.find_all('tr'))[0].find_all('th'):
    headers.append(str(td).replace('\n','')[4:-5])

#Now the rows
rows=[]
for tr in table.find_all('tr'):
    temp=[]
    for td in tr.find_all('td'):
        temp.append(str(td).replace('\n','')[4:-5])
    rows.append(temp)

#remove the first empty row
rows=rows[1:]

#Rename the first header
headers[0]='Postal_Code'

# %%
#print the results
print(headers)
print(rows[0:5])
# Out:
# ['Postal_Code', 'Borough', 'Neighborhood']
# [['M1A', 'Not assigned', ''], ['M2A', 'Not assigned', ''], ['M3A', 'North York', 'Parkwoods'], ['M4A', 'North York', 'Victoria Village'], ['M5A', 'Downtown Toronto', 'Regent Park / Harbourfront']]

# %%
#Now I will create the dataframe
df=pd.DataFrame(rows,columns=headers)
df.head()
# Out:
#   Postal_Code           Borough                Neighborhood
# 0         M1A      Not assigned
# 1         M2A      Not assigned
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %% [markdown]
# #### Now I will do the cleaning

# %%
#First drop the unassigned boroughs
df.drop(index=df[df['Borough']=='Not assigned'].index,inplace=True)

# %%
#Convert the slashes '/' into commmas in Neighborhood column
df['Neighborhood'].replace(' /',',',regex=True,inplace=True)

# %%
#Now I will check if there are duplicates of postal codes and merge any neighborhoods sharing the same postal_code
print(df.count())
print(df['Postal_Code'].unique().size)
# Out:
# Postal_Code     103
# Borough         103
# Neighborhood    103
# dtype: int64
# 103

# %% [markdown]
# #### Note that unique values of the postal_code are the same as the rows in the entire dataframe (103).
# #### This means that there aren't duplicate values for postal_code and we don't need to merge.

# %% [markdown]
# #### Now I will check if there are any unassigned neighborhoods to give them the same name s their borough

# %%
df[df['Neighborhood']=='Not assigned']
# Out:
# Empty DataFrame
# Columns: [Postal_Code, Borough, Neighborhood]
# Index: []

# %% [markdown]
# #### there are none so no further work is required. Now I'm done with the cleaning, the next step is to print the shape of the dataframe, but first I will reindex the dataframe to make it neat.

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#   Postal_Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
print(df.shape)
# Out:
# (103, 3)

# %% [markdown]
# <hr>
#
# ## **PART 2**: Adding Coordinates to the Dataframe

# %%
#read the csv file for coordinates
coodf=pd.read_csv('Geospatial_Coordinates.csv')

# %%
#join the two dataframes using the postal code
newdf=pd.merge(df,coodf,left_on='Postal_Code',right_on='Postal Code',how='left')

#drop the extra postal code column
newdf.drop(columns=['Postal Code'],inplace=True)

# %%
newdf.head()
# Out:
#   Postal_Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# <hr>
#
# ## **PART 3**: Exploration & Clustering

# %%
#First I will get the boroughs that has 'Toronto' in their names

neighborhoods=newdf[newdf['Borough'].str.contains('Toronto')]

# %% [markdown]
# #### Now I will use geopy library to get the coordinates for Toronto, in order to visualize a map with the above boroughs and neighbourhoods.

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto city are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto city are 43.6534817, -79.3839347.

# %%
map_canada = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{} - {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_canada)  
    
map_canada
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Foursquare Credentials

# %%
#I removed the keys for security
#CLIENT_ID = 'PRIVATE'
#CLIENT_SECRET = 'PRIVATE'
VERSION = '20180605'

# %% [markdown]
# #### Now I will use the function to get the nearby venues in order to explore all the postals/neighborhoods in Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500,LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Postal Code', 
                  'Postal Code Latitude', 
                  'Postal Code Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Now I'll get the Toronto venues using the function to get the top 100 avenues close to the postal codes.
# #### NOTE: I decided to go with avenues close to postal codes because postal codes are unique and have multiple neighborhoods. The assignment required that multiple neighborhoods be merged into one row under the same postal code.

# %%
toronto_venues = getNearbyVenues(names=neighborhoods['Postal_Code'],
                                   latitudes=neighborhoods['Latitude'],
                                   longitudes=neighborhoods['Longitude']
                                  );
# Out:
# M5A
# M7A
# M5B
# M5C
# M4E
# M5E
# M5G
# M6G
# M5H
# M6H
# M5J
# M6J
# M4K
# M5K
# M6K
# M4L
# M5L
# M4M
# M4N
# M5N
# M4P
# M5P
# M6P
# M4R
# M5R
# M6R
# M4S
# M5S
# M6S
# M4T
# M5T
# M4V
# M5V
# M4W
# M5W
# M4X
# M5X
# M4Y
# M7Y

# %%
toronto_venues.shape
toronto_venues.head()
# Out:
#   Postal Code  Postal Code Latitude  Postal Code Longitude  \
# 0         M5A              43.65426             -79.360636
# 1         M5A              43.65426             -79.360636
# 2         M5A              43.65426             -79.360636
# 3         M5A              43.65426             -79.360636
# 4         M5A              43.65426             -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2      Morning Glory Cafe       43.653947       -79.361149
# 3  Cooper Koo Family YMCA       43.653249       -79.358008
# 4     Body Blitz Spa East       43.654735       -79.359874
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2       Breakfast Spot
# 3  Distribution Center
# 4                  Spa

# %% [markdown]
# #### checking the number of venues for each postal code

# %%
toronto_venues.groupby('Postal Code').count()
# Out:
#              Postal Code Latitude  Postal Code Longitude  Venue  \
# Postal Code
# M4E                             5                      5      5
# M4K                            43                     43     43
# M4L                            20                     20     20
# M4M                            40                     40     40
# M4N                             3                      3      3
# M4P                             8                      8      8
# M4R                            18                     18     18
# M4S                            33                     33     33
# M4T                             1                      1      1
# M4V                            17                     17     17
# M4W                             4                      4      4
# M4X                            45                     45     45
# M4Y                            77                     77     77
# M5A                            48                     48     48
# M5B                           100                    100    100
# M5C                            79                     79     79
# M5E                            58                     58     58
# M5G                            62                     62     62
# M5H                            95                     95     95
# M5J                           100                    100    100
# M5K                           100                    100    100
# M5L                           100                    100    100
# M5N                             2                      2      2
# M5P                             4                      4      4
# M5R                            24                     24     24
# M5S                            35                     35     35
# M5T                            55                     55     55
# M5V                            16                     16     16
# M5W                            96                     96     96
# M5X                           100                    100    100
# M6G                            17                     17     17
# M6H                            19                     19     19
# M6J                            41                     41     41
# M6K                            24                     24     24
# M6P                            23                     23     23
# M6R                            13                     13     13
# M6S                            39                     39     39
# M7A                            40                     40     40
# M7Y                            16                     16     16
#
#              Venue Latitude  Venue Longitude  Venue Category
# Postal Code
# M4E                       5                5               5
# M4K                      43               43              43
# M4L                      20               20              20
# M4M                      40               40              40
# M4N                       3                3               3
# M4P                       8                8               8
# M4R                      18               18              18
# M4S                      33               33              33
# M4T                       1                1               1
# M4V                      17               17              17
# M4W                       4                4               4
# M4X                      45               45              45
# M4Y                      77               77              77
# M5A                      48               48              48
# M5B                     100              100             100
# M5C                      79               79              79
# M5E                      58               58              58
# M5G                      62               62              62
# M5H                      95               95              95
# M5J                     100              100             100
# M5K                     100              100             100
# M5L                     100              100             100
# M5N                       2                2               2
# M5P                       4                4               4
# M5R                      24               24              24
# M5S                      35               35              35
# M5T                      55               55              55
# M5V                      16               16              16
# M5W                      96               96              96
# M5X                     100              100             100
# M6G                      17               17              17
# M6H                      19               19              19
# M6J                      41               41              41
# M6K                      24               24              24
# M6P                      23               23              23
# M6R                      13               13              13
# M6S                      39               39              39
# M7A                      40               40              40
# M7Y                      16               16              16

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 228 uniques categories.

# %% [markdown]
# #### Now I'm going to analyze the neighborhoods and preprocess the data in order to do the clustering. First I will convert venue categories into dummy variables.

# %%
#make dummy variabbles
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

#add postal code to the dataframe
toronto_onehot['Postal Code'] = toronto_venues['Postal Code'] 


fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# %% [markdown]
# #### Now I will calculate the frequency of venues in postal codes

# %%
toronto_grouped = toronto_onehot.groupby('Postal Code').mean().reset_index()
toronto_grouped
# Out:
#    Postal Code  Airport  Airport Food Court  Airport Gate  Airport Lounge  \
# 0          M4E   0.0000              0.0000        0.0000           0.000
# 1          M4K   0.0000              0.0000        0.0000           0.000
# 2          M4L   0.0000              0.0000        0.0000           0.000
# 3          M4M   0.0000              0.0000        0.0000           0.000
# 4          M4N   0.0000              0.0000        0.0000           0.000
# 5          M4P   0.0000              0.0000        0.0000           0.000
# 6          M4R   0.0000              0.0000        0.0000           0.000
# 7          M4S   0.0000              0.0000        0.0000           0.000
# 8          M4T   0.0000              0.0000        0.0000           0.000
# 9          M4V   0.0000              0.0000        0.0000           0.000
# 10         M4W   0.0000              0.0000        0.0000           0.000
# 11         M4X   0.0000              0.0000        0.0000           0.000
# 12         M4Y   0.0000              0.0000        0.0000           0.000
# 13         M5A   0.0000              0.0000        0.0000           0.000
# 14         M5B   0.0000              0.0000        0.0000           0.000
# 15         M5C   0.0000              0.0000        0.0000           0.000
# 16         M5E   0.0000              0.0000        0.0000           0.000
# 17         M5G   0.0000              0.0000        0.0000           0.000
# 18         M5H   0.0000              0.0000        0.0000           0.000
# 19         M5J   0.0000              0.0000        0.0000           0.000
# 20         M5K   0.0000              0.0000        0.0000           0.000
# 21         M5L   0.0000              0.0000        0.0000           0.000
# 22         M5N   0.0000              0.0000        0.0000           0.000
# 23         M5P   0.0000              0.0000        0.0000           0.000
# 24         M5R   0.0000              0.0000        0.0000           0.000
# 25         M5S   0.0000              0.0000        0.0000           0.000
# 26         M5T   0.0000              0.0000        0.0000           0.000
# 27         M5V   0.0625              0.0625        0.0625           0.125
# 28         M5W   0.0000              0.0000        0.0000           0.000
# 29         M5X   0.0000              0.0000        0.0000           0.000
# 30         M6G   0.0000              0.0000        0.0000           0.000
# 31         M6H   0.0000              0.0000        0.0000           0.000
# 32         M6J   0.0000              0.0000        0.0000           0.000
# 33         M6K   0.0000              0.0000        0.0000           0.000
# 34         M6P   0.0000              0.0000        0.0000           0.000
# 35         M6R   0.0000              0.0000        0.0000           0.000
# 36         M6S   0.0000              0.0000        0.0000           0.000
# 37         M7A   0.0000              0.0000        0.0000           0.000
# 38         M7Y   0.0000              0.0000        0.0000           0.000
#
#     Airport Service  Airport Terminal  American Restaurant  Antique Shop  \
# 0            0.0000             0.000             0.000000      0.000000
# 1            0.0000             0.000             0.023256      0.000000
# 2            0.0000             0.000             0.000000      0.000000
# 3            0.0000             0.000             0.050000      0.000000
# 4            0.0000             0.000             0.000000      0.000000
# 5            0.0000             0.000             0.000000      0.000000
# 6            0.0000             0.000             0.000000      0.000000
# 7            0.0000             0.000             0.000000      0.000000
# 8            0.0000             0.000             0.000000      0.000000
# 9            0.0000             0.000             0.058824      0.000000
# 10           0.0000             0.000             0.000000      0.000000
# 11           0.0000             0.000             0.000000      0.000000
# 12           0.0000             0.000             0.012987      0.000000
# 13           0.0000             0.000             0.000000      0.020833
# 14           0.0000             0.000             0.010000      0.000000
# 15           0.0000             0.000             0.037975      0.000000
# 16           0.0000             0.000             0.000000      0.000000
# 17           0.0000             0.000             0.000000      0.000000
# 18           0.0000             0.000             0.031579      0.000000
# 19           0.0000             0.000             0.000000      0.000000
# 20           0.0000             0.000             0.030000      0.000000
# 21           0.0000             0.000             0.040000      0.000000
# 22           0.0000             0.000             0.000000      0.000000
# 23           0.0000             0.000             0.000000      0.000000
# 24           0.0000             0.000             0.041667      0.000000
# 25           0.0000             0.000             0.000000      0.000000
# 26           0.0000             0.000             0.000000      0.000000
# 27           0.1875             0.125             0.000000      0.000000
# 28           0.0000             0.000             0.010417      0.010417
# 29           0.0000             0.000             0.030000      0.000000
# 30           0.0000             0.000             0.000000      0.000000
# 31           0.0000             0.000             0.000000      0.000000
# 32           0.0000             0.000             0.000000      0.000000
# 33           0.0000             0.000             0.000000      0.000000
# 34           0.0000             0.000             0.000000      0.043478
# 35           0.0000             0.000             0.000000      0.000000
# 36           0.0000             0.000             0.000000      0.000000
# 37           0.0000             0.000             0.000000      0.000000
# 38           0.0000             0.000             0.000000      0.000000
#
#     Aquarium  ...  Theme Restaurant  Toy / Game Store     Trail  \
# 0       0.00  ...          0.000000          0.000000  0.200000
# 1       0.00  ...          0.000000          0.000000  0.023256
# 2       0.00  ...          0.000000          0.000000  0.000000
# 3       0.00  ...          0.000000          0.000000  0.000000
# 4       0.00  ...          0.000000          0.000000  0.000000
# 5       0.00  ...          0.000000          0.000000  0.000000
# 6       0.00  ...          0.000000          0.000000  0.000000
# 7       0.00  ...          0.000000          0.030303  0.000000
# 8       0.00  ...          0.000000          0.000000  0.000000
# 9       0.00  ...          0.000000          0.000000  0.000000
# 10      0.00  ...          0.000000          0.000000  0.250000
# 11      0.00  ...          0.000000          0.000000  0.000000
# 12      0.00  ...          0.012987          0.000000  0.000000
# 13      0.00  ...          0.000000          0.000000  0.000000
# 14      0.00  ...          0.000000          0.000000  0.000000
# 15      0.00  ...          0.000000          0.000000  0.000000
# 16      0.00  ...          0.000000          0.000000  0.000000
# 17      0.00  ...          0.000000          0.000000  0.000000
# 18      0.00  ...          0.000000          0.000000  0.000000
# 19      0.05  ...          0.000000          0.000000  0.000000
# 20      0.00  ...          0.000000          0.000000  0.000000
# 21      0.00  ...          0.000000          0.000000  0.000000
# 22      0.00  ...          0.000000          0.000000  0.000000
# 23      0.00  ...          0.000000          0.000000  0.250000
# 24      0.00  ...          0.000000          0.000000  0.000000
# 25      0.00  ...          0.000000          0.000000  0.000000
# 26      0.00  ...          0.000000          0.000000  0.000000
# 27      0.00  ...          0.000000          0.000000  0.000000
# 28      0.00  ...          0.000000          0.000000  0.000000
# 29      0.00  ...          0.000000          0.000000  0.000000
# 30      0.00  ...          0.000000          0.000000  0.000000
# 31      0.00  ...          0.000000          0.000000  0.000000
# 32      0.00  ...          0.000000          0.000000  0.000000
# 33      0.00  ...          0.000000          0.000000  0.000000
# 34      0.00  ...          0.000000          0.000000  0.000000
# 35      0.00  ...          0.000000          0.000000  0.000000
# 36      0.00  ...          0.000000          0.000000  0.000000
# 37      0.00  ...          0.000000          0.000000  0.000000
# 38      0.00  ...          0.000000          0.000000  0.000000
#
#     Train Station  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0            0.00                       0.000000          0.000000
# 1            0.00                       0.000000          0.000000
# 2            0.00                       0.000000          0.000000
# 3            0.00                       0.000000          0.000000
# 4            0.00                       0.000000          0.000000
# 5            0.00                       0.000000          0.000000
# 6            0.00                       0.000000          0.000000
# 7            0.00                       0.000000          0.000000
# 8            0.00                       0.000000          0.000000
# 9            0.00                       0.000000          0.000000
# 10           0.00                       0.000000          0.000000
# 11           0.00                       0.000000          0.000000
# 12           0.00                       0.000000          0.000000
# 13           0.00                       0.000000          0.000000
# 14           0.00                       0.000000          0.010000
# 15           0.00                       0.012658          0.000000
# 16           0.00                       0.017241          0.000000
# 17           0.00                       0.016129          0.000000
# 18           0.00                       0.010526          0.000000
# 19           0.01                       0.010000          0.000000
# 20           0.01                       0.010000          0.000000
# 21           0.00                       0.020000          0.000000
# 22           0.00                       0.000000          0.000000
# 23           0.00                       0.000000          0.000000
# 24           0.00                       0.041667          0.000000
# 25           0.00                       0.000000          0.028571
# 26           0.00                       0.036364          0.000000
# 27           0.00                       0.000000          0.000000
# 28           0.00                       0.010417          0.000000
# 29           0.01                       0.010000          0.000000
# 30           0.00                       0.000000          0.000000
# 31           0.00                       0.000000          0.000000
# 32           0.00                       0.048780          0.000000
# 33           0.00                       0.000000          0.000000
# 34           0.00                       0.000000          0.000000
# 35           0.00                       0.000000          0.000000
# 36           0.00                       0.025641          0.000000
# 37           0.00                       0.000000          0.000000
# 38           0.00                       0.000000          0.000000
#
#     Vietnamese Restaurant  Wine Bar  Women's Store  Yoga Studio
# 0                0.000000  0.000000       0.000000     0.000000
# 1                0.000000  0.000000       0.000000     0.023256
# 2                0.000000  0.000000       0.000000     0.000000
# 3                0.000000  0.025000       0.000000     0.025000
# 4                0.000000  0.000000       0.000000     0.000000
# 5                0.000000  0.000000       0.000000     0.000000
# 6                0.000000  0.000000       0.000000     0.055556
# 7                0.000000  0.000000       0.000000     0.000000
# 8                0.000000  0.000000       0.000000     0.000000
# 9                0.058824  0.000000       0.000000     0.000000
# 10               0.000000  0.000000       0.000000     0.000000
# 11               0.000000  0.000000       0.000000     0.000000
# 12               0.000000  0.000000       0.000000     0.025974
# 13               0.000000  0.000000       0.000000     0.020833
# 14               0.010000  0.000000       0.000000     0.000000
# 15               0.000000  0.012658       0.000000     0.000000
# 16               0.000000  0.000000       0.000000     0.000000
# 17               0.000000  0.000000       0.000000     0.016129
# 18               0.000000  0.000000       0.010526     0.000000
# 19               0.000000  0.010000       0.000000     0.000000
# 20               0.000000  0.010000       0.000000     0.000000
# 21               0.000000  0.010000       0.000000     0.000000
# 22               0.000000  0.000000       0.000000     0.000000
# 23               0.000000  0.000000       0.000000     0.000000
# 24               0.000000  0.000000       0.000000     0.000000
# 25               0.000000  0.000000       0.000000     0.028571
# 26               0.054545  0.018182       0.000000     0.000000
# 27               0.000000  0.000000       0.000000     0.000000
# 28               0.000000  0.000000       0.000000     0.010417
# 29               0.000000  0.010000       0.000000     0.000000
# 30               0.000000  0.000000       0.000000     0.000000
# 31               0.000000  0.000000       0.000000     0.000000
# 32               0.048780  0.024390       0.000000     0.024390
# 33               0.000000  0.000000       0.000000     0.000000
# 34               0.000000  0.000000       0.000000     0.000000
# 35               0.000000  0.000000       0.000000     0.000000
# 36               0.000000  0.000000       0.000000     0.000000
# 37               0.000000  0.000000       0.000000     0.025000
# 38               0.000000  0.000000       0.000000     0.000000
#
# [39 rows x 229 columns]

# %%
num_top_venues = 5

for code in toronto_grouped['Postal Code']:
    print("----"+code+"----")
    temp = toronto_grouped[toronto_grouped['Postal Code'] == code].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----M4E----
#                venue  freq
# 0       Neighborhood   0.2
# 1  Health Food Store   0.2
# 2                Pub   0.2
# 3        Coffee Shop   0.2
# 4              Trail   0.2
#
#
# ----M4K----
#                     venue  freq
# 0        Greek Restaurant  0.19
# 1             Coffee Shop  0.09
# 2      Italian Restaurant  0.07
# 3          Ice Cream Shop  0.05
# 4  Furniture / Home Store  0.05
#
#
# ----M4L----
#                   venue  freq
# 0  Fast Food Restaurant  0.10
# 1                  Park  0.10
# 2      Sushi Restaurant  0.05
# 3                   Pub  0.05
# 4               Brewery  0.05
#
#
# ----M4M----
#          venue  freq
# 0         Café  0.10
# 1  Coffee Shop  0.08
# 2      Brewery  0.05
# 3       Bakery  0.05
# 4    Gastropub  0.05
#
#
# ----M4N----
#            venue  freq
# 0           Park  0.33
# 1       Bus Line  0.33
# 2    Swim School  0.33
# 3        Airport  0.00
# 4  Movie Theater  0.00
#
#
# ----M4P----
#                venue  freq
# 0                Gym  0.12
# 1              Hotel  0.12
# 2     Sandwich Place  0.12
# 3   Department Store  0.12
# 4  Food & Drink Shop  0.12
#
#
# ----M4R----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1       Clothing Store  0.11
# 2        Grocery Store  0.06
# 3                 Café  0.06
# 4  Sporting Goods Shop  0.06
#
#
# ----M4S----
#             venue  freq
# 0    Dessert Shop  0.09
# 1  Sandwich Place  0.09
# 2            Café  0.06
# 3             Gym  0.06
# 4     Coffee Shop  0.06
#
#
# ----M4T----
#                venue  freq
# 0         Playground   1.0
# 1            Airport   0.0
# 2      Movie Theater   0.0
# 3             Market   0.0
# 4  Martial Arts Dojo   0.0
#
#
# ----M4V----
#                      venue  freq
# 0                      Pub  0.12
# 1              Coffee Shop  0.12
# 2  Health & Beauty Service  0.06
# 3             Liquor Store  0.06
# 4       Light Rail Station  0.06
#
#
# ----M4W----
#            venue  freq
# 0           Park  0.50
# 1     Playground  0.25
# 2          Trail  0.25
# 3        Airport  0.00
# 4  Movie Theater  0.00
#
#
# ----M4X----
#          venue  freq
# 0  Coffee Shop  0.09
# 1       Bakery  0.07
# 2   Restaurant  0.07
# 3  Pizza Place  0.04
# 4         Café  0.04
#
#
# ----M4Y----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1     Sushi Restaurant  0.08
# 2  Japanese Restaurant  0.06
# 3           Restaurant  0.04
# 4          Yoga Studio  0.03
#
#
# ----M5A----
#             venue  freq
# 0     Coffee Shop  0.17
# 1            Park  0.06
# 2             Pub  0.06
# 3          Bakery  0.06
# 4  Breakfast Spot  0.04
#
#
# ----M5B----
#                  venue  freq
# 0       Clothing Store  0.09
# 1          Coffee Shop  0.09
# 2                 Café  0.04
# 3       Cosmetics Shop  0.03
# 4  Japanese Restaurant  0.03
#
#
# ----M5C----
#                  venue  freq
# 0                 Café  0.06
# 1          Coffee Shop  0.06
# 2   Italian Restaurant  0.04
# 3         Cocktail Bar  0.04
# 4  American Restaurant  0.04
#
#
# ----M5E----
#             venue  freq
# 0     Coffee Shop  0.07
# 1    Cocktail Bar  0.05
# 2  Farmers Market  0.03
# 3        Beer Bar  0.03
# 4            Café  0.03
#
#
# ----M5G----
#                 venue  freq
# 0         Coffee Shop  0.21
# 1  Italian Restaurant  0.06
# 2                Café  0.05
# 3      Sandwich Place  0.05
# 4     Bubble Tea Shop  0.03
#
#
# ----M5H----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1                 Café  0.05
# 2           Restaurant  0.04
# 3       Clothing Store  0.03
# 4  American Restaurant  0.03
#
#
# ----M5J----
#             venue  freq
# 0     Coffee Shop  0.13
# 1        Aquarium  0.05
# 2            Café  0.04
# 3           Hotel  0.04
# 4  Scenic Lookout  0.03
#
#
# ----M5K----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                Hotel  0.08
# 2                 Café  0.07
# 3           Restaurant  0.04
# 4  Japanese Restaurant  0.04
#
#
# ----M5L----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1           Restaurant  0.07
# 2                 Café  0.07
# 3                Hotel  0.06
# 4  American Restaurant  0.04
#
#
# ----M5N----
#                       venue  freq
# 0            Ice Cream Shop   0.5
# 1                    Garden   0.5
# 2               Music Venue   0.0
# 3         Martial Arts Dojo   0.0
# 4  Mediterranean Restaurant   0.0
#
#
# ----M5P----
#               venue  freq
# 0              Park  0.25
# 1     Jewelry Store  0.25
# 2             Trail  0.25
# 3  Sushi Restaurant  0.25
# 4           Airport  0.00
#
#
# ----M5R----
#                venue  freq
# 0               Café  0.12
# 1     Sandwich Place  0.12
# 2        Coffee Shop  0.08
# 3  Indian Restaurant  0.04
# 4        Flower Shop  0.04
#
#
# ----M5S----
#                  venue  freq
# 0                 Café  0.14
# 1                  Bar  0.06
# 2               Bakery  0.06
# 3            Bookstore  0.06
# 4  Japanese Restaurant  0.06
#
#
# ----M5T----
#                    venue  freq
# 0                   Café  0.09
# 1            Coffee Shop  0.07
# 2                 Bakery  0.05
# 3  Vietnamese Restaurant  0.05
# 4     Mexican Restaurant  0.05
#
#
# ----M5V----
#                 venue  freq
# 0     Airport Service  0.19
# 1      Airport Lounge  0.12
# 2    Airport Terminal  0.12
# 3             Airport  0.06
# 4  Airport Food Court  0.06
#
#
# ----M5W----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1                Café  0.04
# 2  Italian Restaurant  0.04
# 3          Restaurant  0.03
# 4        Cocktail Bar  0.03
#
#
# ----M5X----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.08
# 2                Hotel  0.05
# 3  Japanese Restaurant  0.04
# 4           Restaurant  0.04
#
#
# ----M6G----
#            venue  freq
# 0  Grocery Store  0.24
# 1           Café  0.18
# 2           Park  0.12
# 3      Nightclub  0.06
# 4    Candy Store  0.06
#
#
# ----M6H----
#          venue  freq
# 0     Pharmacy  0.11
# 1       Bakery  0.11
# 2  Gas Station  0.05
# 3  Pizza Place  0.05
# 4         Park  0.05
#
#
# ----M6J----
#                            venue  freq
# 0                            Bar  0.10
# 1                     Restaurant  0.07
# 2          Vietnamese Restaurant  0.05
# 3  Vegetarian / Vegan Restaurant  0.05
# 4                    Men's Store  0.05
#
#
# ----M6K----
#             venue  freq
# 0       Nightclub  0.12
# 1            Café  0.12
# 2     Coffee Shop  0.08
# 3  Breakfast Spot  0.08
# 4   Grocery Store  0.04
#
#
# ----M6P----
#                        venue  freq
# 0         Mexican Restaurant  0.09
# 1            Thai Restaurant  0.09
# 2                       Café  0.09
# 3  Cajun / Creole Restaurant  0.04
# 4                  Speakeasy  0.04
#
#
# ----M6R----
#                          venue  freq
# 0                    Gift Shop  0.15
# 1                    Bookstore  0.08
# 2                  Coffee Shop  0.08
# 3                Movie Theater  0.08
# 4  Eastern European Restaurant  0.08
#
#
# ----M6S----
#                 venue  freq
# 0         Pizza Place  0.08
# 1                Café  0.08
# 2         Coffee Shop  0.05
# 3  Italian Restaurant  0.05
# 4                 Pub  0.05
#
#
# ----M7A----
#                 venue  freq
# 0         Coffee Shop  0.28
# 1    Sushi Restaurant  0.08
# 2               Diner  0.05
# 3  Italian Restaurant  0.02
# 4            Creperie  0.02
#
#
# ----M7Y----
#               venue  freq
# 0       Pizza Place  0.06
# 1     Garden Center  0.06
# 2        Comic Shop  0.06
# 3  Recording Studio  0.06
# 4        Restaurant  0.06

# %% [markdown]
# #### Here, I will be extracting the 10 most common venues for each postal code of toronto

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Postal Code']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
postal_venues_sorted = pd.DataFrame(columns=columns)
postal_venues_sorted['Postal Code'] = toronto_grouped['Postal Code']

for ind in np.arange(toronto_grouped.shape[0]):
    postal_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

postal_venues_sorted.head()
# Out:
#   Postal Code 1st Most Common Venue 2nd Most Common Venue  \
# 0         M4E           Coffee Shop                   Pub
# 1         M4K      Greek Restaurant           Coffee Shop
# 2         M4L                  Park  Fast Food Restaurant
# 3         M4M                  Café           Coffee Shop
# 4         M4N                  Park              Bus Line
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                 Trail          Neighborhood     Health Food Store
# 1    Italian Restaurant             Bookstore        Ice Cream Shop
# 2           Coffee Shop    Light Rail Station        Sandwich Place
# 3   American Restaurant               Brewery                Bakery
# 4           Swim School    Falafel Restaurant           Event Space
#
#     6th Most Common Venue    7th Most Common Venue  \
# 0             Yoga Studio      Distribution Center
# 1  Furniture / Home Store  Fruit & Vegetable Store
# 2            Liquor Store            Burrito Place
# 3               Gastropub              Yoga Studio
# 4    Ethiopian Restaurant        Electronics Store
#
#          8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                 Dessert Shop                 Diner         Discount Store
# 1                          Pub           Pizza Place                 Lounge
# 2           Italian Restaurant            Restaurant         Ice Cream Shop
# 3                        Diner             Bookstore     Seafood Restaurant
# 4  Eastern European Restaurant            Donut Shop       Doner Restaurant

# %% [markdown]
# #### Now I will move on to clustering

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Postal Code', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 4, 4, 4, 2, 4, 4, 4, 1, 4], dtype=int32)

# %%
#postal_venues_sorted.drop(columns=['Cluster Labels'],axis=1,inplace=True)
postal_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_merged = neighborhoods

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(postal_venues_sorted.set_index('Postal Code'), on='Postal_Code')

# %%
toronto_merged.head()
# Out:
#    Postal_Code           Borough                                 Neighborhood  \
# 2          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 4          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 9          M5B  Downtown Toronto                     Garden District, Ryerson
# 15         M5C  Downtown Toronto                               St. James Town
# 19         M4E      East Toronto                                  The Beaches
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 2   43.654260 -79.360636               4           Coffee Shop
# 4   43.662301 -79.389494               4           Coffee Shop
# 9   43.657162 -79.378937               4           Coffee Shop
# 15  43.651494 -79.375418               4                  Café
# 19  43.676357 -79.293031               0           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 2                   Park                Bakery                   Pub
# 4       Sushi Restaurant                 Diner           Yoga Studio
# 9         Clothing Store                  Café            Restaurant
# 15           Coffee Shop          Cocktail Bar             Gastropub
# 19                   Pub                 Trail          Neighborhood
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 2         Breakfast Spot               Theater                  Café
# 4               Creperie        Sandwich Place          Burger Joint
# 9    Japanese Restaurant       Bubble Tea Shop        Cosmetics Shop
# 15    Italian Restaurant   American Restaurant      Department Store
# 19     Health Food Store           Yoga Studio   Distribution Center
#
#         8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 2                 Yoga Studio            Restaurant             Beer Store
# 4               Burrito Place                  Café     College Auditorium
# 9   Middle Eastern Restaurant  Fast Food Restaurant              Bookstore
# 15             Farmers Market                 Hotel             Restaurant
# 19               Dessert Shop                 Diner         Discount Store

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Postal_Code'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Observations

# %%
#Cluster 0
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 19      East Toronto               0           Coffee Shop
# 68   Central Toronto               0                  Park
# 91  Downtown Toronto               0                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 19                   Pub                 Trail          Neighborhood
# 68         Jewelry Store                 Trail      Sushi Restaurant
# 91            Playground                 Trail          Dance Studio
#
#    5th Most Common Venue 6th Most Common Venue        7th Most Common Venue  \
# 19     Health Food Store           Yoga Studio          Distribution Center
# 68           Yoga Studio         Deli / Bodega            Electronics Store
# 91  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
#
#           8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 19                 Dessert Shop                 Diner         Discount Store
# 68  Eastern European Restaurant            Donut Shop       Doner Restaurant
# 91                   Donut Shop      Doner Restaurant                Dog Run

# %%
#Cluster 1
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 83  Central Toronto               1            Playground
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 83           Yoga Studio         Deli / Bodega  Ethiopian Restaurant
#
#    5th Most Common Venue        6th Most Common Venue 7th Most Common Venue  \
# 83     Electronics Store  Eastern European Restaurant            Donut Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 83      Doner Restaurant               Dog Run    Distribution Center

# %%
#Cluster 2
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 61  Central Toronto               2                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 61              Bus Line           Swim School    Falafel Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 61           Event Space  Ethiopian Restaurant     Electronics Store
#
#           8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 61  Eastern European Restaurant            Donut Shop       Doner Restaurant

# %%
#Cluster 3
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 62  Central Toronto               3        Ice Cream Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 62                Garden           Yoga Studio  Ethiopian Restaurant
#
#    5th Most Common Venue        6th Most Common Venue 7th Most Common Venue  \
# 62     Electronics Store  Eastern European Restaurant            Donut Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 62      Doner Restaurant               Dog Run    Distribution Center

# %%
#Cluster 4
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 2    Downtown Toronto               4           Coffee Shop
# 4    Downtown Toronto               4           Coffee Shop
# 9    Downtown Toronto               4           Coffee Shop
# 15   Downtown Toronto               4                  Café
# 20   Downtown Toronto               4           Coffee Shop
# 24   Downtown Toronto               4           Coffee Shop
# 25   Downtown Toronto               4         Grocery Store
# 30   Downtown Toronto               4           Coffee Shop
# 31       West Toronto               4              Pharmacy
# 36   Downtown Toronto               4           Coffee Shop
# 37       West Toronto               4                   Bar
# 41       East Toronto               4      Greek Restaurant
# 42   Downtown Toronto               4           Coffee Shop
# 43       West Toronto               4             Nightclub
# 47       East Toronto               4                  Park
# 48   Downtown Toronto               4           Coffee Shop
# 54       East Toronto               4                  Café
# 67    Central Toronto               4     Food & Drink Shop
# 69       West Toronto               4    Mexican Restaurant
# 73    Central Toronto               4           Coffee Shop
# 74    Central Toronto               4        Sandwich Place
# 75       West Toronto               4             Gift Shop
# 79    Central Toronto               4        Sandwich Place
# 80   Downtown Toronto               4                  Café
# 81       West Toronto               4           Pizza Place
# 84   Downtown Toronto               4                  Café
# 86    Central Toronto               4                   Pub
# 87   Downtown Toronto               4       Airport Service
# 92   Downtown Toronto               4           Coffee Shop
# 96   Downtown Toronto               4           Coffee Shop
# 97   Downtown Toronto               4           Coffee Shop
# 99   Downtown Toronto               4           Coffee Shop
# 100      East Toronto               4                  Park
#
#     2nd Most Common Venue  3rd Most Common Venue  4th Most Common Venue  \
# 2                    Park                 Bakery                    Pub
# 4        Sushi Restaurant                  Diner            Yoga Studio
# 9          Clothing Store                   Café             Restaurant
# 15            Coffee Shop           Cocktail Bar              Gastropub
# 20           Cocktail Bar                   Café                 Bakery
# 24     Italian Restaurant         Sandwich Place                   Café
# 25                   Café                   Park             Baby Store
# 30                   Café             Restaurant          Deli / Bodega
# 31                 Bakery                   Park           Liquor Store
# 36               Aquarium                   Café                  Hotel
# 37             Restaurant            Men's Store  Vietnamese Restaurant
# 41            Coffee Shop     Italian Restaurant              Bookstore
# 42                  Hotel                   Café             Restaurant
# 43                   Café            Coffee Shop         Breakfast Spot
# 47   Fast Food Restaurant            Coffee Shop     Light Rail Station
# 48                   Café             Restaurant                  Hotel
# 54            Coffee Shop    American Restaurant                Brewery
# 67                   Park         Breakfast Spot                    Gym
# 69                   Café        Thai Restaurant                 Bakery
# 73         Clothing Store            Yoga Studio    Sporting Goods Shop
# 74                   Café            Coffee Shop                   Park
# 75       Cuban Restaurant           Dessert Shop              Bookstore
# 79           Dessert Shop            Coffee Shop     Italian Restaurant
# 80                    Bar     Italian Restaurant    Japanese Restaurant
# 81                   Café            Coffee Shop       Sushi Restaurant
# 84            Coffee Shop  Vietnamese Restaurant                 Bakery
# 86            Coffee Shop            Supermarket             Sports Bar
# 87         Airport Lounge       Airport Terminal                Airport
# 92                   Café     Italian Restaurant                  Hotel
# 96                 Bakery             Restaurant                   Café
# 97                   Café                  Hotel                    Gym
# 99       Sushi Restaurant    Japanese Restaurant             Restaurant
# 100           Pizza Place                Brewery             Skate Park
#
#     5th Most Common Venue          6th Most Common Venue  \
# 2          Breakfast Spot                        Theater
# 4                Creperie                 Sandwich Place
# 9     Japanese Restaurant                Bubble Tea Shop
# 15     Italian Restaurant            American Restaurant
# 20            Cheese Shop                 Farmers Market
# 24         Ice Cream Shop                            Bar
# 25            Candy Store                     Restaurant
# 30                    Gym            American Restaurant
# 31                   Café      Middle Eastern Restaurant
# 36         Scenic Lookout                        Brewery
# 37       Asian Restaurant  Vegetarian / Vegan Restaurant
# 41         Ice Cream Shop         Furniture / Home Store
# 42    Japanese Restaurant             Seafood Restaurant
# 43                    Bar                   Climbing Gym
# 47         Sandwich Place                   Liquor Store
# 48                    Gym            American Restaurant
# 54                 Bakery                      Gastropub
# 67                  Hotel              Convenience Store
# 69                  Diner                            Bar
# 73          Grocery Store           Fast Food Restaurant
# 74      Indian Restaurant                    Flower Shop
# 75                    Bar                  Movie Theater
# 79            Pizza Place                            Gym
# 80              Bookstore                     Restaurant
# 81                    Pub                     Restaurant
# 84     Mexican Restaurant                            Bar
# 86             Bagel Shop               Sushi Restaurant
# 87        Harbor / Marina                            Bar
# 92             Restaurant             Seafood Restaurant
# 96            Pizza Place             Italian Restaurant
# 97    Japanese Restaurant                     Restaurant
# 99            Men's Store                     Smoke Shop
# 100            Smoke Shop                  Burrito Place
#
#              7th Most Common Venue      8th Most Common Venue  \
# 2                             Café                Yoga Studio
# 4                     Burger Joint              Burrito Place
# 9                   Cosmetics Shop  Middle Eastern Restaurant
# 15                Department Store             Farmers Market
# 20              Seafood Restaurant                   Beer Bar
# 24                 Thai Restaurant                Salad Place
# 25              Italian Restaurant                      Diner
# 30                           Hotel            Thai Restaurant
# 31                             Bar                       Bank
# 36             Sporting Goods Shop                 Restaurant
# 37                            Café                Yoga Studio
# 41         Fruit & Vegetable Store                        Pub
# 42                     Salad Place        American Restaurant
# 43                   Burrito Place                 Restaurant
# 47                   Burrito Place         Italian Restaurant
# 48              Italian Restaurant         Seafood Restaurant
# 54                     Yoga Studio                      Diner
# 67                Department Store             Sandwich Place
# 69                     Flea Market         Italian Restaurant
# 73                           Diner               Dessert Shop
# 74                             Pub  Middle Eastern Restaurant
# 75              Italian Restaurant                    Dog Run
# 79                Sushi Restaurant                       Café
# 80                          Bakery                Yoga Studio
# 81              Italian Restaurant  South American Restaurant
# 84   Vegetarian / Vegan Restaurant                Gaming Cafe
# 86             Fried Chicken Joint                Pizza Place
# 87                Sculpture Garden                Coffee Shop
# 92                    Cocktail Bar                   Beer Bar
# 96                             Pub       Caribbean Restaurant
# 97                Asian Restaurant         Seafood Restaurant
# 99                             Pub                Pizza Place
# 100                 Farmers Market       Fast Food Restaurant
#
#          9th Most Common Venue       10th Most Common Venue
# 2                   Restaurant                   Beer Store
# 4                         Café           College Auditorium
# 9         Fast Food Restaurant                    Bookstore
# 15                       Hotel                   Restaurant
# 20                  Restaurant        Portuguese Restaurant
# 24                Burger Joint              Bubble Tea Shop
# 25                 Coffee Shop                    Nightclub
# 30              Clothing Store             Sushi Restaurant
# 31                     Brewery                         Pool
# 36         Fried Chicken Joint           Italian Restaurant
# 37         Japanese Restaurant                    Juice Bar
# 41                 Pizza Place                       Lounge
# 42               Deli / Bodega                     Beer Bar
# 43          Italian Restaurant                 Intersection
# 47                  Restaurant               Ice Cream Shop
# 48               Deli / Bodega          Japanese Restaurant
# 54                   Bookstore           Seafood Restaurant
# 67                 Yoga Studio                        Diner
# 69   Cajun / Creole Restaurant          Fried Chicken Joint
# 73          Mexican Restaurant           Chinese Restaurant
# 74                  Donut Shop                    BBQ Joint
# 75                 Coffee Shop  Eastern European Restaurant
# 79            Greek Restaurant                        Diner
# 80                         Pub                     Beer Bar
# 81          Falafel Restaurant          Indie Movie Theater
# 84                Dessert Shop                  Cheese Shop
# 86     Health & Beauty Service                         Bank
# 87               Boat or Ferry                     Boutique
# 92         Japanese Restaurant                       Bakery
# 96                    Pharmacy                   Playground
# 97                  Steakhouse                  Salad Place
# 99                     Gay Bar                  Yoga Studio
# 100                 Restaurant             Recording Studio

# %% [markdown]
# #### It seems that cluster 4 contains the postal codes which has cafes/bakery/resturants as popular avenues, while other clusters have stores/playgrounds/etc. as popular avenues.
